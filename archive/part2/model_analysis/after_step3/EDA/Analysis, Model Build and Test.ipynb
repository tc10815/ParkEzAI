# %%
import os
import json
import numpy as np
import pandas as pd
import torch
from torch import nn, optim
import torchvision.transforms as transforms
from PIL import Image
from torch.utils.data import Dataset
from torch.utils.data import DataLoader

# %%
with open('full_input_original_human_labels.json', 'r') as file:
    human_dict = json.load(file)
    
with open('full_input_original_model_labels.json', 'r') as file:
    model_dict = json.load(file)
    
spot_keys = list(human_dict[list(human_dict.keys())[0]].keys())

# %%
def build_df(method_keys):
    totals = {}
    errors = {}
    false_positives = {}
    false_negatives = {}
    for spot_key in spot_keys:
        totals[spot_key] = 0
        errors[spot_key] = 0
        false_positives[spot_key] = 0
        false_negatives[spot_key] = 0

    for key in method_keys:
        for spot_key in spot_keys:
            if(human_dict[key][spot_key]):
                totals[spot_key] = totals[spot_key] + 1
            if(human_dict[key][spot_key] != model_dict[key][spot_key]):
                errors[spot_key] = errors[spot_key] + 1
                if(not human_dict[key][spot_key]):
                    false_positives[spot_key] = false_positives[spot_key] + 1
                else:
                    false_negatives[spot_key] = false_negatives[spot_key] + 1

    # Create a structured numpy array
    dtype = [('Times Occupied', int), ('Errors', int), ('False Positives', int), ('False Negatives', int)]
    values = [(totals[key], errors[key], false_positives[key], false_negatives[key]) for key in totals.keys()]
    structured_np = np.array(values, dtype=dtype)
    df = pd.DataFrame(structured_np)

    # Calculate True Negatives
    df["True Negatives"] = len(method_keys) - df["False Negatives"]

    # Calculate Accuracy
    df["Accuracy"] = (df["Times Occupied"] + df["True Negatives"]) / (df["Times Occupied"] + df["True Negatives"] + df["False Positives"] + df["False Negatives"])

    # Calculate Precision
    df["Precision"] = df["Times Occupied"] / (df["Times Occupied"] + df["False Positives"])

    # Calculate Recall
    df["Recall"] = df["Times Occupied"] / (df["Times Occupied"] + df["False Negatives"])

    # Calculate F1 Score
    df["F1 Score"] = 2 * (df["Precision"] * df["Recall"]) / (df["Precision"] + df["Recall"])
    df.index = ['A1', 'A2', 'A3', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6']
    df = df.round(2)
    return df

# %%
def build_df_dict(method_keys, meth_dict):
    totals = {}
    errors = {}
    false_positives = {}
    false_negatives = {}
    for spot_key in spot_keys:
        totals[spot_key] = 0
        errors[spot_key] = 0
        false_positives[spot_key] = 0
        false_negatives[spot_key] = 0

    for key in method_keys:
        for spot_key in spot_keys:
            if(human_dict[key][spot_key]):
                totals[spot_key] = totals[spot_key] + 1
            if(human_dict[key][spot_key] != meth_dict[key][spot_key]):
                errors[spot_key] = errors[spot_key] + 1
                if(not human_dict[key][spot_key]):
                    false_positives[spot_key] = false_positives[spot_key] + 1
                else:
                    false_negatives[spot_key] = false_negatives[spot_key] + 1

    # Create a structured numpy array
    dtype = [('Times Occupied', int), ('Errors', int), ('False Positives', int), ('False Negatives', int)]
    values = [(totals[key], errors[key], false_positives[key], false_negatives[key]) for key in totals.keys()]
    structured_np = np.array(values, dtype=dtype)
    df = pd.DataFrame(structured_np)

    # Calculate True Negatives
    df["True Negatives"] = len(method_keys) - df["False Negatives"]

    # Calculate Accuracy
    df["Accuracy"] = (df["Times Occupied"] + df["True Negatives"]) / (df["Times Occupied"] + df["True Negatives"] + df["False Positives"] + df["False Negatives"])

    # Calculate Precision
    df["Precision"] = df["Times Occupied"] / (df["Times Occupied"] + df["False Positives"])

    # Calculate Recall
    df["Recall"] = df["Times Occupied"] / (df["Times Occupied"] + df["False Negatives"])

    # Calculate F1 Score
    df["F1 Score"] = 2 * (df["Precision"] * df["Recall"]) / (df["Precision"] + df["Recall"])
    df.index = ['A1', 'A2', 'A3', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6']
    df = df.round(2)
    return df

# %%
interval = 3
count = 0
total = 0
ordered_keys = list(human_dict.keys())
ordered_keys.sort()
training_keys = []
testing_keys = []
# for key in ordered_keys:
#     print(str(count) + ' ' + key[12:24], end='')
#     if(human_dict[key][spot_key] != model_dict[key][spot_key]):
#         print('-xxxxxx', end='')
#     print('',end='\n')
#     count = count + 1

# Model doesn't make a mistake for 
training_keys = ordered_keys[0:171] 
testing_keys = ordered_keys[171:]

# %%
build_df(training_keys)
# Out:
#     Times Occupied  Errors  False Positives  False Negatives  True Negatives  \
# A1              33       1                1                0             171
# A2              37       0                0                0             171
# A3              28       1                0                1             170
# B1              22       0                0                0             171
# B2              27       0                0                0             171
# B3              69       2                2                0             171
# B4              71       0                0                0             171
# B5             119       1                1                0             171
# B6              89       0                0                0             171
#
#     Accuracy  Precision  Recall  F1 Score
# A1      1.00       0.97    1.00      0.99
# A2      1.00       1.00    1.00      1.00
# A3      0.99       1.00    0.97      0.98
# B1      1.00       1.00    1.00      1.00
# B2      1.00       1.00    1.00      1.00
# B3      0.99       0.97    1.00      0.99
# B4      1.00       1.00    1.00      1.00
# B5      1.00       0.99    1.00      1.00
# B6      1.00       1.00    1.00      1.00

# %%
build_df(testing_keys[:-150])
# Out:
#     Times Occupied  Errors  False Positives  False Negatives  True Negatives  \
# A1              24       6                6                0              60
# A2              26      11               11                0              60
# A3              23       1                0                1              59
# B1              20       3                1                2              58
# B2              18      19               19                0              60
# B3              29      15               15                0              60
# B4              19       4                4                0              60
# B5              29      15               15                0              60
# B6              13       5                5                0              60
#
#     Accuracy  Precision  Recall  F1 Score
# A1      0.93       0.80    1.00      0.89
# A2      0.89       0.70    1.00      0.83
# A3      0.99       1.00    0.96      0.98
# B1      0.96       0.95    0.91      0.93
# B2      0.80       0.49    1.00      0.65
# B3      0.86       0.66    1.00      0.79
# B4      0.95       0.83    1.00      0.90
# B5      0.86       0.66    1.00      0.79
# B6      0.94       0.72    1.00      0.84

# %%
print(len(training_keys))
print(len(testing_keys))
# Out:
# 171
# 210

# %%
# CNN model good at determining if car in spot, from notebook, will separate to another file eventually for organization
class CNN(nn.Module):
    def __init__(self):
        super(CNN, self).__init__()
        
        # Convolutional layer 1
        self.conv1 = nn.Conv2d(3, 32, kernel_size=3, stride=1, padding=1)
        self.bn1 = nn.BatchNorm2d(32)
        self.relu1 = nn.ReLU()
        
        # Max pool layer
        self.pool = nn.MaxPool2d(kernel_size=2)

        # Convolutional layer 2
        self.conv2 = nn.Conv2d(32, 64, kernel_size=3, stride=1, padding=1)
        self.bn2 = nn.BatchNorm2d(64)
        self.relu2 = nn.ReLU()

        # Fully connected layers
        self.fc1 = nn.Linear(64 * 32 * 32, 128)
        self.fc2 = nn.Linear(128, 2)

    def forward(self, x):
        # Convolutional layer 1
        out = self.conv1(x)
        out = self.bn1(out)
        out = self.relu1(out)

        # Max pool layer
        out = self.pool(out)

        # Convolutional layer 2
        out = self.conv2(out)
        out = self.bn2(out)
        out = self.relu2(out)

        # Max pool layer
        out = self.pool(out)

        # Flatten for fully connected layer
        out = out.view(out.size(0), -1)

        # Fully connected layer 1
        out = self.fc1(out)

        # Fully connected layer 2
        out = self.fc2(out)
        return out

# Originally in Model_Maker notebook, this preps cropped parking spaces for ML processing
transform = transforms.Compose([
    transforms.Resize((128, 128)),  # Resize images to 128x128
    transforms.ToTensor(),  # Convert images to PyTorch tensor
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))  # Normalize pixel values in the range [-1, 1]
])

# %%
def get_models():
    old_models = {}
    for key in spot_keys:
        model_path = os.path.join('Archive', 'old_models', key + '.pth')
        old_models[key] = CNN()
        old_models[key].load_state_dict(torch.load(model_path)) 
        old_models[key].eval() 
    return old_models

def predict_image(to_predict_image, predicting_model_dict):
    ret = {}
    for key in spot_keys:
        dir_name = 'input'
        full_path = os.path.join(dir_name, to_predict_image)
        image = Image.open(full_path)
        spots_file_path = os.path.join('Archive', 'old_models', 'spots.json')
        with open(spots_file_path, 'r') as spots_file:
            spots_data = json.load(spots_file)
        x, x_w, y, y_h = spots_data[key]
        cropped_image = image.crop((x, y, x_w, y_h))
        input_tensor = transform(cropped_image)
        input_tensor = input_tensor.unsqueeze(0)
        with torch.no_grad():
            output = predicting_model_dict[key](input_tensor)
            _, predicted = torch.max(output, 1)

        prediction = predicted.item()
        ret[key] = False
        if prediction == 0: ret[key] = True
    return ret

def bulk_predict(keys, predicting_model_dict):
    ret = {}
    for x in keys:
        ret[x] = predict_image(x, predicting_model_dict)
    return ret

# %%
recent_model_results = bulk_predict(list(human_dict.keys()), get_models())

# %%
build_df_dict(testing_keys, recent_model_results)
# Out:
#     Times Occupied  Errors  False Positives  False Negatives  True Negatives  \
# A1              65      25               20                5             205
# A2              82      22               22                0             210
# A3              85       3                2                1             209
# B1              50       4                1                3             207
# B2              65      19               19                0             210
# B3             119      31               31                0             210
# B4              79       4                4                0             210
# B5              86      75               75                0             210
# B6              80      52               35               17             193
#
#     Accuracy  Precision  Recall  F1 Score
# A1      0.92       0.76    0.93      0.84
# A2      0.93       0.79    1.00      0.88
# A3      0.99       0.98    0.99      0.98
# B1      0.98       0.98    0.94      0.96
# B2      0.94       0.77    1.00      0.87
# B3      0.91       0.79    1.00      0.88
# B4      0.99       0.95    1.00      0.98
# B5      0.80       0.53    1.00      0.70
# B6      0.84       0.70    0.82      0.75

# %%
build_df(testing_keys)
# Out:
#     Times Occupied  Errors  False Positives  False Negatives  True Negatives  \
# A1              65      25               20                5             205
# A2              82      22               22                0             210
# A3              85       3                2                1             209
# B1              50       4                1                3             207
# B2              65      19               19                0             210
# B3             119      31               31                0             210
# B4              79       4                4                0             210
# B5              86      75               75                0             210
# B6              80      52               35               17             193
#
#     Accuracy  Precision  Recall  F1 Score
# A1      0.92       0.76    0.93      0.84
# A2      0.93       0.79    1.00      0.88
# A3      0.99       0.98    0.99      0.98
# B1      0.98       0.98    0.94      0.96
# B2      0.94       0.77    1.00      0.87
# B3      0.91       0.79    1.00      0.88
# B4      0.99       0.95    1.00      0.98
# B5      0.80       0.53    1.00      0.70
# B6      0.84       0.70    0.82      0.75

# %%
class LotImageDataset(Dataset):
    def __init__(self, img_dict, label_dict, transform=None):
        self.img_dict = img_dict
        self.label_dict = label_dict
        self.transform = transform

    def __len__(self):
        return len(self.img_dict)

    def __getitem__(self, idx):
        img_name = list(self.img_dict.keys())[idx]
        image = self.img_dict[img_name]
        label = self.label_dict[img_name]
        if self.transform:
            image = self.transform(image)
        return image, label

# %%
def get_dataset_params(my_dict, selected_keys, spot, spot_locs):
    labels_dict = {}
    images_dict = {}
    for to_predict_image in selected_keys:
        dir_name = 'input'
        image_path = os.path.join(dir_name, to_predict_image)
        to_crop = Image.open(image_path)
        x, x_w, y, y_h = spot_locs[spot]
        images_dict[to_predict_image] = to_crop.crop((x, y, x_w, y_h))
        pred = 1
        if my_dict[to_predict_image][spot]: pred = 0
        labels_dict[to_predict_image] = pred
    return images_dict, labels_dict

# %%
spots_file_path = os.path.join('Archive', 'old_models', 'spots.json')
with open(spots_file_path, 'r') as spots_file:
    spots_data = json.load(spots_file)

# %%
# Dictionary to store the models
models_dict = {}

# Prepare the model for each parking space
for parking_space in spot_keys:
    images, labels = get_dataset_params(human_dict, training_keys, parking_space, spots_data)
    dataset = LotImageDataset(images, labels, transform=transform)
    dataloader = DataLoader(dataset, batch_size=32, shuffle=True)

    # Use the previously defined CNN class
    model = CNN()
    print(f'{parking_space}: Success!!')

    # Define loss and optimizer
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

    # Number of epochs to train for
    num_epochs = 25

    # Move model to GPU if available
    if torch.cuda.is_available():
        model = model.cuda()

    # Train the model
    for epoch in range(num_epochs):
        model.train()  # set the model to training mode
        train_loss = 0.0
        for i, (inputs, labels) in enumerate(dataloader):
            # Move data and labels to GPU if available
            if torch.cuda.is_available():
                inputs = inputs.cuda()
                labels = labels.cuda()

            # Clear the gradients
            optimizer.zero_grad()

            # Forward pass
            outputs = model(inputs)
            loss = criterion(outputs, labels)

            # Backward and optimize
            loss.backward()
            optimizer.step()

            train_loss += loss.item() * inputs.size(0)

        train_loss = train_loss / len(dataloader.dataset)

        print('Parking Space: {}, Epoch {}, Loss: {:.4f}'.format(parking_space, epoch + 1, train_loss))

    print('Finished Training for parking space ', parking_space)

    # save the model after training
    torch.save(model.state_dict(), f"{parking_space}_model.pth")

    # add the model to the dictionary
    models_dict[parking_space] = model
# Out:
# A1: Success!!
# Parking Space: A1, Epoch 1, Loss: 0.5772
# Parking Space: A1, Epoch 2, Loss: 0.8374
# Parking Space: A1, Epoch 3, Loss: 0.0212
# Parking Space: A1, Epoch 4, Loss: 0.0094
# Parking Space: A1, Epoch 5, Loss: 0.0000
# Parking Space: A1, Epoch 6, Loss: 0.0000
# Parking Space: A1, Epoch 7, Loss: 0.0000
# Parking Space: A1, Epoch 8, Loss: 0.0000
# Parking Space: A1, Epoch 9, Loss: 0.0000
# Parking Space: A1, Epoch 10, Loss: 0.0000
# Parking Space: A1, Epoch 11, Loss: 0.0000
# Parking Space: A1, Epoch 12, Loss: 0.0000
# Parking Space: A1, Epoch 13, Loss: 0.0000
# Parking Space: A1, Epoch 14, Loss: 0.0000
# Parking Space: A1, Epoch 15, Loss: 0.0000
# Parking Space: A1, Epoch 16, Loss: 0.0000
# Parking Space: A1, Epoch 17, Loss: 0.0000
# Parking Space: A1, Epoch 18, Loss: 0.0000
# Parking Space: A1, Epoch 19, Loss: 0.0000
# Parking Space: A1, Epoch 20, Loss: 0.0000
# Parking Space: A1, Epoch 21, Loss: 0.0000
# Parking Space: A1, Epoch 22, Loss: 0.0000
# Parking Space: A1, Epoch 23, Loss: 0.0000
# Parking Space: A1, Epoch 24, Loss: 0.0000
# Parking Space: A1, Epoch 25, Loss: 0.0000
# Finished Training for parking space  A1
# A2: Success!!
# Parking Space: A2, Epoch 1, Loss: 16.6844
# Parking Space: A2, Epoch 2, Loss: 0.4642
# Parking Space: A2, Epoch 3, Loss: 0.0439
# Parking Space: A2, Epoch 4, Loss: 0.0000
# Parking Space: A2, Epoch 5, Loss: 0.0000
# Parking Space: A2, Epoch 6, Loss: 0.0000
# Parking Space: A2, Epoch 7, Loss: 0.0000
# Parking Space: A2, Epoch 8, Loss: 0.0000
# Parking Space: A2, Epoch 9, Loss: 0.0000
# Parking Space: A2, Epoch 10, Loss: 0.0000
# Parking Space: A2, Epoch 11, Loss: 0.0000
# Parking Space: A2, Epoch 12, Loss: 0.1943
# Parking Space: A2, Epoch 13, Loss: 0.0000
# Parking Space: A2, Epoch 14, Loss: 0.0000
# Parking Space: A2, Epoch 15, Loss: 0.0000
# Parking Space: A2, Epoch 16, Loss: 0.0000
# Parking Space: A2, Epoch 17, Loss: 0.0000
# Parking Space: A2, Epoch 18, Loss: 0.0000
# Parking Space: A2, Epoch 19, Loss: 0.0000
# Parking Space: A2, Epoch 20, Loss: 0.0000
# Parking Space: A2, Epoch 21, Loss: 0.0000
# Parking Space: A2, Epoch 22, Loss: 0.0000
# Parking Space: A2, Epoch 23, Loss: 0.0000
# Parking Space: A2, Epoch 24, Loss: 0.0000
# Parking Space: A2, Epoch 25, Loss: 0.0000
# Finished Training for parking space  A2
# A3: Success!!
# Parking Space: A3, Epoch 1, Loss: 2.7844
# Parking Space: A3, Epoch 2, Loss: 0.0000
# Parking Space: A3, Epoch 3, Loss: 0.0000
# Parking Space: A3, Epoch 4, Loss: 0.0000
# Parking Space: A3, Epoch 5, Loss: 0.0193
# Parking Space: A3, Epoch 6, Loss: 0.0000
# Parking Space: A3, Epoch 7, Loss: 0.2282
# Parking Space: A3, Epoch 8, Loss: 0.0000
# Parking Space: A3, Epoch 9, Loss: 0.0000
# Parking Space: A3, Epoch 10, Loss: 0.1188
# Parking Space: A3, Epoch 11, Loss: 0.0000
# Parking Space: A3, Epoch 12, Loss: 0.0000
# Parking Space: A3, Epoch 13, Loss: 0.0000
# Parking Space: A3, Epoch 14, Loss: 0.0000
# Parking Space: A3, Epoch 15, Loss: 0.0000
# Parking Space: A3, Epoch 16, Loss: 0.0000
# Parking Space: A3, Epoch 17, Loss: 0.0000
# Parking Space: A3, Epoch 18, Loss: 0.0000
# Parking Space: A3, Epoch 19, Loss: 0.0000
# Parking Space: A3, Epoch 20, Loss: 0.0000
# Parking Space: A3, Epoch 21, Loss: 0.0000
# Parking Space: A3, Epoch 22, Loss: 0.0000
# Parking Space: A3, Epoch 23, Loss: 0.0000
# Parking Space: A3, Epoch 24, Loss: 0.0000
# Parking Space: A3, Epoch 25, Loss: 0.0000
# Finished Training for parking space  A3
# B1: Success!!
# Parking Space: B1, Epoch 1, Loss: 1.0639
# Parking Space: B1, Epoch 2, Loss: 0.6612
# Parking Space: B1, Epoch 3, Loss: 0.1489
# Parking Space: B1, Epoch 4, Loss: 0.6261
# Parking Space: B1, Epoch 5, Loss: 0.0000
# Parking Space: B1, Epoch 6, Loss: 0.1344
# Parking Space: B1, Epoch 7, Loss: 0.0000
# Parking Space: B1, Epoch 8, Loss: 0.0000
# Parking Space: B1, Epoch 9, Loss: 0.0000
# Parking Space: B1, Epoch 10, Loss: 0.1399
# Parking Space: B1, Epoch 11, Loss: 0.0000
# Parking Space: B1, Epoch 12, Loss: 0.0000
# Parking Space: B1, Epoch 13, Loss: 0.0000
# Parking Space: B1, Epoch 14, Loss: 0.0000
# Parking Space: B1, Epoch 15, Loss: 0.0000
# Parking Space: B1, Epoch 16, Loss: 0.0174
# Parking Space: B1, Epoch 17, Loss: 0.0000
# Parking Space: B1, Epoch 18, Loss: 0.0000
# Parking Space: B1, Epoch 19, Loss: 0.0000
# Parking Space: B1, Epoch 20, Loss: 0.0000
# Parking Space: B1, Epoch 21, Loss: 0.0000
# Parking Space: B1, Epoch 22, Loss: 0.0000
# Parking Space: B1, Epoch 23, Loss: 0.0003
# Parking Space: B1, Epoch 24, Loss: 0.0000
# Parking Space: B1, Epoch 25, Loss: 0.0000
# Finished Training for parking space  B1
# B2: Success!!
# Parking Space: B2, Epoch 1, Loss: 13.9490
# Parking Space: B2, Epoch 2, Loss: 1.0682
# Parking Space: B2, Epoch 3, Loss: 0.0000
# Parking Space: B2, Epoch 4, Loss: 0.0000
# Parking Space: B2, Epoch 5, Loss: 0.0000
# Parking Space: B2, Epoch 6, Loss: 0.0000
# Parking Space: B2, Epoch 7, Loss: 0.0000
# Parking Space: B2, Epoch 8, Loss: 0.0000
# Parking Space: B2, Epoch 9, Loss: 0.0000
# Parking Space: B2, Epoch 10, Loss: 0.0000
# Parking Space: B2, Epoch 11, Loss: 0.0000
# Parking Space: B2, Epoch 12, Loss: 0.0000
# Parking Space: B2, Epoch 13, Loss: 0.0000
# Parking Space: B2, Epoch 14, Loss: 0.0000
# Parking Space: B2, Epoch 15, Loss: 0.0000
# Parking Space: B2, Epoch 16, Loss: 0.0000
# Parking Space: B2, Epoch 17, Loss: 0.0000
# Parking Space: B2, Epoch 18, Loss: 0.0000
# Parking Space: B2, Epoch 19, Loss: 0.0000
# Parking Space: B2, Epoch 20, Loss: 0.0000
# Parking Space: B2, Epoch 21, Loss: 0.0000
# Parking Space: B2, Epoch 22, Loss: 0.0000
# Parking Space: B2, Epoch 23, Loss: 0.0000
# Parking Space: B2, Epoch 24, Loss: 0.0000
# Parking Space: B2, Epoch 25, Loss: 0.0000
# Finished Training for parking space  B2
# B3: Success!!
# Parking Space: B3, Epoch 1, Loss: 3.5946
# Parking Space: B3, Epoch 2, Loss: 1.4215
# Parking Space: B3, Epoch 3, Loss: 0.0682
# Parking Space: B3, Epoch 4, Loss: 0.0000
# Parking Space: B3, Epoch 5, Loss: 0.0000
# Parking Space: B3, Epoch 6, Loss: 0.0000
# Parking Space: B3, Epoch 7, Loss: 0.0000
# Parking Space: B3, Epoch 8, Loss: 0.0851
# Parking Space: B3, Epoch 9, Loss: 0.0000
# Parking Space: B3, Epoch 10, Loss: 0.0000
# Parking Space: B3, Epoch 11, Loss: 0.0000
# Parking Space: B3, Epoch 12, Loss: 0.0000
# Parking Space: B3, Epoch 13, Loss: 0.0000
# Parking Space: B3, Epoch 14, Loss: 0.0000
# Parking Space: B3, Epoch 15, Loss: 0.0000
# Parking Space: B3, Epoch 16, Loss: 0.0000
# Parking Space: B3, Epoch 17, Loss: 0.0000
# Parking Space: B3, Epoch 18, Loss: 0.0000
# Parking Space: B3, Epoch 19, Loss: 0.0000
# Parking Space: B3, Epoch 20, Loss: 0.0000
# Parking Space: B3, Epoch 21, Loss: 0.0000
# Parking Space: B3, Epoch 22, Loss: 0.0000
# Parking Space: B3, Epoch 23, Loss: 0.0000
# Parking Space: B3, Epoch 24, Loss: 0.0000
# Parking Space: B3, Epoch 25, Loss: 0.0000
# Finished Training for parking space  B3
# B4: Success!!
# Parking Space: B4, Epoch 1, Loss: 5.8048
# Parking Space: B4, Epoch 2, Loss: 0.0000
# Parking Space: B4, Epoch 3, Loss: 0.9100
# Parking Space: B4, Epoch 4, Loss: 0.0000
# Parking Space: B4, Epoch 5, Loss: 0.0000
# Parking Space: B4, Epoch 6, Loss: 0.0000
# Parking Space: B4, Epoch 7, Loss: 0.0000
# Parking Space: B4, Epoch 8, Loss: 0.0000
# Parking Space: B4, Epoch 9, Loss: 0.0928
# Parking Space: B4, Epoch 10, Loss: 0.0000
# Parking Space: B4, Epoch 11, Loss: 0.0000
# Parking Space: B4, Epoch 12, Loss: 0.0000
# Parking Space: B4, Epoch 13, Loss: 0.0000
# Parking Space: B4, Epoch 14, Loss: 0.0000
# Parking Space: B4, Epoch 15, Loss: 0.0000
# Parking Space: B4, Epoch 16, Loss: 0.0000
# Parking Space: B4, Epoch 17, Loss: 0.0000
# Parking Space: B4, Epoch 18, Loss: 0.0000
# Parking Space: B4, Epoch 19, Loss: 0.0000
# Parking Space: B4, Epoch 20, Loss: 0.0000
# Parking Space: B4, Epoch 21, Loss: 0.0000
# Parking Space: B4, Epoch 22, Loss: 0.0000
# Parking Space: B4, Epoch 23, Loss: 0.0000
# Parking Space: B4, Epoch 24, Loss: 0.0000
# Parking Space: B4, Epoch 25, Loss: 0.0000
# Finished Training for parking space  B4
# B5: Success!!
# Parking Space: B5, Epoch 1, Loss: 47.1819
# Parking Space: B5, Epoch 2, Loss: 8.1609
# Parking Space: B5, Epoch 3, Loss: 0.6932
# Parking Space: B5, Epoch 4, Loss: 0.6932
# Parking Space: B5, Epoch 5, Loss: 0.0000
# Parking Space: B5, Epoch 6, Loss: 0.0000
# Parking Space: B5, Epoch 7, Loss: 0.0000
# Parking Space: B5, Epoch 8, Loss: 0.0000
# Parking Space: B5, Epoch 9, Loss: 0.0000
# Parking Space: B5, Epoch 10, Loss: 0.0000
# Parking Space: B5, Epoch 11, Loss: 0.0000
# Parking Space: B5, Epoch 12, Loss: 0.0000
# Parking Space: B5, Epoch 13, Loss: 0.0000
# Parking Space: B5, Epoch 14, Loss: 0.0000
# Parking Space: B5, Epoch 15, Loss: 0.0000
# Parking Space: B5, Epoch 16, Loss: 0.0000
# Parking Space: B5, Epoch 17, Loss: 0.0000
# Parking Space: B5, Epoch 18, Loss: 0.0000
# Parking Space: B5, Epoch 19, Loss: 0.0000
# Parking Space: B5, Epoch 20, Loss: 0.0000
# Parking Space: B5, Epoch 21, Loss: 0.0000
# Parking Space: B5, Epoch 22, Loss: 0.0000
# Parking Space: B5, Epoch 23, Loss: 0.0000
# Parking Space: B5, Epoch 24, Loss: 0.0000
# Parking Space: B5, Epoch 25, Loss: 0.0000
# Finished Training for parking space  B5
# B6: Success!!
# Parking Space: B6, Epoch 1, Loss: 7.0924
# Parking Space: B6, Epoch 2, Loss: 0.3037
# Parking Space: B6, Epoch 3, Loss: 0.3493
# Parking Space: B6, Epoch 4, Loss: 0.0000
# Parking Space: B6, Epoch 5, Loss: 0.0000
# Parking Space: B6, Epoch 6, Loss: 0.0000
# Parking Space: B6, Epoch 7, Loss: 0.0000
# Parking Space: B6, Epoch 8, Loss: 0.0000
# Parking Space: B6, Epoch 9, Loss: 0.0000
# Parking Space: B6, Epoch 10, Loss: 0.0000
# Parking Space: B6, Epoch 11, Loss: 0.0000
# Parking Space: B6, Epoch 12, Loss: 0.0000
# Parking Space: B6, Epoch 13, Loss: 0.0000
# Parking Space: B6, Epoch 14, Loss: 0.0000
# Parking Space: B6, Epoch 15, Loss: 0.0000
# Parking Space: B6, Epoch 16, Loss: 0.0000
# Parking Space: B6, Epoch 17, Loss: 0.0000
# Parking Space: B6, Epoch 18, Loss: 0.0000
# Parking Space: B6, Epoch 19, Loss: 0.0000
# Parking Space: B6, Epoch 20, Loss: 0.0000
# Parking Space: B6, Epoch 21, Loss: 0.0000
# Parking Space: B6, Epoch 22, Loss: 0.0000
# Parking Space: B6, Epoch 23, Loss: 0.0000
# Parking Space: B6, Epoch 24, Loss: 0.0000
# Parking Space: B6, Epoch 25, Loss: 0.0000
# Finished Training for parking space  B6

# %%
for model_key in models_dict.keys():
    models_dict[model_key].eval() 

fresh_model_results = bulk_predict(testing_keys, models_dict)

# %%
fresh_trained_results = build_df_dict(testing_keys, fresh_model_results)
fresh_trained_results
# Out:
#     Times Occupied  Errors  False Positives  False Negatives  True Negatives  \
# A1              65      26               26                0             210
# A2              82      15               15                0             210
# A3              85       9                9                0             210
# B1              50       2                1                1             209
# B2              65       3                0                3             207
# B3             119       9                9                0             210
# B4              79       5                5                0             210
# B5              86      13               11                2             208
# B6              80      39               35                4             206
#
#     Accuracy  Precision  Recall  F1 Score
# A1      0.91       0.71    1.00      0.83
# A2      0.95       0.85    1.00      0.92
# A3      0.97       0.90    1.00      0.95
# B1      0.99       0.98    0.98      0.98
# B2      0.99       1.00    0.96      0.98
# B3      0.97       0.93    1.00      0.96
# B4      0.98       0.94    1.00      0.97
# B5      0.96       0.89    0.98      0.93
# B6      0.88       0.70    0.95      0.80

# %%
pickled_results = build_df_dict(testing_keys, recent_model_results)
pickled_results
# Out:
#     Times Occupied  Errors  False Positives  False Negatives  True Negatives  \
# A1              65      25               20                5             205
# A2              82      22               22                0             210
# A3              85       3                2                1             209
# B1              50       4                1                3             207
# B2              65      19               19                0             210
# B3             119      31               31                0             210
# B4              79       4                4                0             210
# B5              86      75               75                0             210
# B6              80      52               35               17             193
#
#     Accuracy  Precision  Recall  F1 Score
# A1      0.92       0.76    0.93      0.84
# A2      0.93       0.79    1.00      0.88
# A3      0.99       0.98    0.99      0.98
# B1      0.98       0.98    0.94      0.96
# B2      0.94       0.77    1.00      0.87
# B3      0.91       0.79    1.00      0.88
# B4      0.99       0.95    1.00      0.98
# B5      0.80       0.53    1.00      0.70
# B6      0.84       0.70    0.82      0.75

# %%
print(f"Total pickled errors {pickled_results['Errors'].sum()}, FN {pickled_results['False Negatives'].sum()}, FP {pickled_results['False Positives'].sum()}")
print(f"Total  fresh  errors {fresh_trained_results['Errors'].sum()}, FN {fresh_trained_results['False Negatives'].sum()}, FP {fresh_trained_results['False Positives'].sum()}")
# Out:
# Total pickled errors 235, FN 26, FP 209
# Total  fresh  errors 121, FN 10, FP 111

# %%
images, labels = get_dataset_params(human_dict, training_keys, 'A1', spots_data)
dataset = LotImageDataset(images, labels, transform=transform)
